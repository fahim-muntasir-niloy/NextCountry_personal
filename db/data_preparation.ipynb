# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# load credentials
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
ASTRA_DB_APPLICATION_TOKEN = os.getenv("ASTRA_DB_APPLICATION_TOKEN")
ASTRA_DB_API_ENDPOINT = os.getenv("ASTRA_DB_API_ENDPOINT")

# %% [markdown]
# ## Load documents

# %%
# load quiz question flow
from langchain_community.document_loaders import DirectoryLoader, PyMuPDFLoader, Docx2txtLoader


folder_path = "D:\\NextCountry_personal\\db"

# quiz_path = "D:\\NextCountry_personal\\db\\ignore"


# quiz_loader = DirectoryLoader(
#     quiz_path,
#     glob="*.docx",
#     loader_cls=Docx2txtLoader,
#     show_progress=True
# )

# quiz_docs = quiz_loader.load()


pdf_loader = DirectoryLoader(
    folder_path,
    glob="*.pdf",
    loader_cls=PyMuPDFLoader,
    show_progress=True
)

doc_loader = DirectoryLoader(
    folder_path,
    glob="*.docx",
    loader_cls=Docx2txtLoader,
    show_progress=True
)

pdfs = pdf_loader.load()
docs = doc_loader.load()
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 29.86it/s]
# 100%|██████████| 2/2 [00:00<00:00, 29.66it/s]

# %%
Documents = pdfs+docs

# %%
from langchain.chat_models import init_chat_model

llm = init_chat_model(
    model="gemini-2.0-flash",
    model_provider="google_genai",
    temperature=0.5,   
)

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter  

text_splitter = RecursiveCharacterTextSplitter(
chunk_size = 1000,
chunk_overlap = 300,
    separators=[
    "\n"]
)

splits = text_splitter.split_documents(Documents)

# %%
len(splits)
# Out:
# 231

# %%
splits[50].metadata
# Out:
# {'producer': 'Skia/PDF m139 Google Docs Renderer',
#  'creator': '',
#  'creationdate': '',
#  'source': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf',
#  'file_path': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf',
#  'total_pages': 24,
#  'format': 'PDF 1.4',
#  'title': 'Practioner Notes For LLM',
#  'author': '',
#  'subject': '',
#  'keywords': '',
#  'moddate': '',
#  'trapped': '',
#  'modDate': '',
#  'creationDate': '',
#  'page': 10}

# %%
# Function to extract country from filename using LLM
def extract_country_from_filename(filename):
    prompt = f"""
    Extract the country name from this filename: {filename}. Then recall the full form of the country name.
    you must return the country name in full form and all capital letters, nothing else.
    example1:'USA visa details' will return 'UNITED STATES OF AMERICA'.
    example2:'BD visa details' will return 'BANGLADESH'.
    If no country is found, return 'NA'.
    """
    response = llm.invoke(prompt)
    return response.content.strip()

# update metadata
def update_metadata(splits):
    
    for i in range(len(splits)):
        filename = splits[i].metadata["source"]
        if i == 0 or filename != splits[i-1].metadata["source"]:
            country = extract_country_from_filename(filename)
        splits[i].metadata["country"] = country
        
    return splits

# %%
documents = update_metadata(splits)
documents[50].metadata
# Out:
# {'producer': 'Skia/PDF m139 Google Docs Renderer',
#  'creator': '',
#  'creationdate': '',
#  'source': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf',
#  'file_path': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf',
#  'total_pages': 24,
#  'format': 'PDF 1.4',
#  'title': 'Practioner Notes For LLM',
#  'author': '',
#  'subject': '',
#  'keywords': '',
#  'moddate': '',
#  'trapped': '',
#  'modDate': '',
#  'creationDate': '',
#  'page': 10,
#  'country': 'NA'}

# %% [markdown]
# ## Embedding Engine
# ---

# %%
# from langchain_google_genai import GoogleGenerativeAIEmbeddings

# google_embedding_model = GoogleGenerativeAIEmbeddings(
#     model="models/text-embedding-004",
# )

from langchain_ollama import OllamaEmbeddings
embedding_engine = OllamaEmbeddings(
    base_url="http://54.80.168.47:11434",
    model="bge-m3:latest",
)

# %% [markdown]
# ## Vector Database Connection

# %%
from astrapy import DataAPIClient

# Initialize the client
client = DataAPIClient(ASTRA_DB_APPLICATION_TOKEN)
db = client.get_database_by_api_endpoint(
  ASTRA_DB_API_ENDPOINT
)

print(f"Connected Database: {db.info().name}\nCollections found: {db.list_collection_names()}")
# Out:
# Connected Database: nc-vec-db
# Collections found: ['quiz_flow', 'visa_details']

# %%
# create collection
from langchain_astradb import AstraDBVectorStore

vector_store = AstraDBVectorStore(
    collection_name="nc_visa_details_vector_db",      # this collection gets created automatically
    embedding=embedding_engine,
    api_endpoint=ASTRA_DB_API_ENDPOINT,
    token=ASTRA_DB_APPLICATION_TOKEN,
    namespace="default_keyspace",
    # autodetect_collection=True,   # set to True whille using it
)

print(f"Connected to collection: {vector_store.collection_name}")
# Out:
# Connected to collection: nc_visa_details_vector_db

# %% [markdown]
# ### Pushing data to collection

# %%
# push embedding to collection
for i in range(0, len(splits), 10):
    chunk = splits[i:i+10]
    try:
        # Add the chunk to the vector store
        vector_store.add_documents(documents=chunk)
        print(f"Chunk {i//10} added successfully")
    except Exception as e:
        print(f"Error adding chunk {i//10 }: {e}")
        continue
# Out:
# Chunk 0 added successfully
# Chunk 1 added successfully
# Chunk 2 added successfully
# Chunk 3 added successfully
# Chunk 4 added successfully
# Chunk 5 added successfully
# Chunk 6 added successfully
# Chunk 7 added successfully
# Chunk 8 added successfully
# Chunk 9 added successfully
# Chunk 10 added successfully
# Chunk 11 added successfully
# Chunk 12 added successfully
# Chunk 13 added successfully
# Chunk 14 added successfully
# Chunk 15 added successfully
# Chunk 16 added successfully
# Chunk 17 added successfully
# Chunk 18 added successfully
# Chunk 19 added successfully
# Chunk 20 added successfully
# Chunk 21 added successfully
# Chunk 22 added successfully
# Chunk 23 added successfully

# %%
print(f"Embeddings loaded to: {vector_store.collection_name}")
# Out:
# Embeddings loaded to: nc_visa_details_vector_db

# %% [markdown]
# ## Check Embeddings

# %%
# sanity check for similarity search
results = vector_store.similarity_search_with_score(
    query="How to get PR/Citizenship from Startup in England",
    k=15,
    # filter={"country": "CANADA"}
)
for res, score in results:
    print(f" --->[Similarity score={score:3f}]\n{res.page_content}\n[{res.metadata}]\n")
# Out:
#  --->[Similarity score=0.816783]
# 3.​ If successful -  receive endorsement letter.
# 4.​ Apply online for visa (outside or inside UK).
# 5.​ Attend biometric appointment and provide documents.
# 6.​ Visa granted for 3 years; leads to Indefinite Leave to Remain (subject to conditions).
# 7.​ Apply for British Citizenship after one year from ILR.
# 🧠 Business Requirements:
# ●​ Business plan must show:
# ○​ Market research, customer pain points.
# ○​ Differentiation and UK market fit.
# ○​ Operational structure and founder commitment.
# ○​ Realistic financials and team plan.
# ○​ How it is innovative, viable, scalable and original.
# ●​ Founders must maintain day-to-day involvement in operations.
# 👨‍👩‍👧 Family Relocation:
# ●​ Spouse and children under 18 can join.
# ●​ Spouse can work without restriction; children can attend school.
# 📈 PR & Citizenship:
# ●​ ILR after 3 years if business meets success criteria (2 of 7 benchmarks, e.g., job
# creation, customer base growth).
# ●​ Citizenship eligible 1 year after ILR.
# [{'producer': 'Skia/PDF m139 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'file_path': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'total_pages': 24, 'format': 'PDF 1.4', 'title': 'Practioner Notes For LLM', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 1, 'country': 'NA'}]
#
#  --->[Similarity score=0.816195]
# 📈 PR & Citizenship:
# ●​ PR granted after successful business and security checks.
# ●​ Citizenship after 3 years of physical presence in Canada (within 5 years).
# 🆕 2025 Policy Highlights:
# ●​ 10 startup limit per designated organization per year.
# ●​ Preference for AI, cleantech, and SaaS startups.
# ●​ Centralized digital submission system introduced.
# ⚠️ Common Pitfalls:
# ●​ Incubator Rejection: Most incubators are highly competitive and require traction, MVP,
# and team credibility.
# ●​ Funding Confusion: For VC/Angel route, a formal legal commitment—not just
# interest—is needed.
# ●​ Passive Founders: IRCC will refuse cases where founders aren’t actively involved or
# treat SUV as a passive immigration route.
# ●​ PR Timeline Misjudgment: Some founders apply too late or without understanding the
# long wait for PR. Many fail to activate the work permit.
# ●​ Equity Structure Mistakes: If one founder holds >50%, and others are minor
# [{'producer': 'Skia/PDF m139 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'file_path': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'total_pages': 24, 'format': 'PDF 1.4', 'title': 'Practioner Notes For LLM', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 3, 'country': 'NA'}]
#
#  --->[Similarity score=0.807618]
# required.
# ●​ Underestimating Integration Requirements: Even if residency is granted, long-term
# PR and citizenship require French language ability and cultural integration. Founders
# must plan early for B1 proficiency and civic compliance.
#
#
# ---
#
# 🇮🇪 Ireland – Start-Up Entrepreneur Programme (STEP)
# [{'producer': 'Skia/PDF m139 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'file_path': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'total_pages': 24, 'format': 'PDF 1.4', 'title': 'Practioner Notes For LLM', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 7, 'country': 'NA'}]
#
#  --->[Similarity score=0.798852]
# o
# British citizenship eligible after 6 years total stay (with ILR + naturalisation)
# •
# Family Sponsorship:
# o
# Spouses and children under 18 can accompany visa holder
# o
# Work and study rights for dependents included
# o
# Financial maintenance and accommodation proof required
#
# Common Red Flags (Visa Denial Triggers)
# •
# Business plan lacks innovation, scalability, or local economic relevance
# •
# Failure to demonstrate viable revenue model or realistic customer acquisition
# •
# No proof of investment (Innovator route) or insufficient startup runway (Start-up route)
# •
# Weak founder track record or no commitment to reside and operate from the Isle of Man
# •
# Overemphasis on UK expansion without intent to build locally first
#
# How to Maximize Success (Approval Checklist)
# •
# Engage the Department for Enterprise early for endorsement guidance
# •
# Draft a detailed business plan showing innovation, scalability, and relevance to the
# [{'producer': 'macOS Version 14.6 (Build 23G80) Quartz PDFContext', 'creator': 'Word', 'creationdate': "D:20250702141310Z00'00'", 'source': 'D:\\NextCountry_personal\\db\\STARTUP LAW; Group 2 Countries.pdf', 'file_path': 'D:\\NextCountry_personal\\db\\STARTUP LAW; Group 2 Countries.pdf', 'total_pages': 24, 'format': 'PDF 1.3', 'title': 'Group 2 Countries', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20250702141310Z00'00'", 'trapped': '', 'modDate': "D:20250702141310Z00'00'", 'creationDate': "D:20250702141310Z00'00'", 'page': 6, 'country': 'NA'}]
#
#  --->[Similarity score=0.798011]
# Prepared by:
# Rafsan Kamal, NextCountry
#
#
# Master Document
# Startup Visa Programs (2025)
# Group 1 Countries: UK; Australia, Germany, New Zealand, Canada, Portugal, Netherlands,
# France, Ireland and Singapore
# Purpose: This document consolidates verified, up-to-date legal pathways for startup visa
# programs across 10 key jurisdictions.
#
#
#
# 🇬🇧 United Kingdom – Innovator Founder Visa
#
# 📋 Eligibility:
# ●​ Endorsement: Must obtain from a Home Office-approved endorsing body (e.g.,
# Envestors, Innovator International).
# ●​ Innovation Criteria: The idea must be INNOVATIVE, ORIGINAL, SCALEABLE, and
# VIABLE —no franchises or standard models.
# ●​ Age & Language: Applicant must be 18+ and meet CEFR B2 English level (IELTS 5.5
# equivalent).
# ●​ Maintenance Funds: Must show personal savings of at least £1,270 maintained for 28
# days.
# ●​ Investment Requirement: No longer mandatory for most.
# 🧾 Application Process:
# [{'producer': 'Skia/PDF m139 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'file_path': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'total_pages': 24, 'format': 'PDF 1.4', 'title': 'Practioner Notes For LLM', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0, 'country': 'NA'}]
#
#  --->[Similarity score=0.795859]
# treat SUV as a passive immigration route.
# ●​ PR Timeline Misjudgment: Some founders apply too late or without understanding the
# long wait for PR. Many fail to activate the work permit.
# ●​ Equity Structure Mistakes: If one founder holds >50%, and others are minor
# shareholders, it may trigger questions about founder alignment.
# ●​ Poor Communication with IRCC: Applicants must respond quickly to requests or face
# file closure. Many rejections come from missing a simple email.
# ●​ Generic Pitches: Innovation must be explained with Canadian market entry logic—not
# just copied from other country plans.
#
# 🇮🇪 Ireland – Start-Up Entrepreneur Programme (STEP)
#
# 📋 Eligibility:
# ●​ Funding: Minimum €50,000 from personal savings, angel investment, or venture capital.
# ●​ Business Innovation: Must be scalable, job-creating, and export-oriented.
# ●​ Founder Role: Applicant must play an active role in development and management.
# ●​ Ownership: More than 50% ownership of the Irish legal entity.
# [{'producer': 'Skia/PDF m139 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'file_path': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'total_pages': 24, 'format': 'PDF 1.4', 'title': 'Practioner Notes For LLM', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 3, 'country': 'NA'}]
#
#  --->[Similarity score=0.795595]
# Innovative: Original, unique, or new to the UK market.
#
# Viable: Realistic, with potential for growth and job creation.
#
# Scalable: Potential for national/international expansion.
#
# B. Same Business Criteria (for those previously endorsed)
#
# Previous Endorsement: 10 points for previous leave as Innovator Founder, Start-up, or Tier 1 Graduate Entrepreneur, and continuing the same business.
#
# Active, Trading, Sustainable: 20 points for a business that is active, trading, and has made significant achievements.
#
# Active Involvement: 20 points for being actively involved in management and development.
#
# C. English Language Requirement
#
# Level: B2 (upper-intermediate) in speaking, listening, reading, and writing.
#
# Evidence: IELTS/approved test, degree taught in English, or nationality from a majority English-speaking country.
#
# D. Financial Requirement
#
# Personal Savings: Must have at least £1,270 held for 28 consecutive days before application, unless in the UK for 12+ months.
# [{'source': 'D:\\NextCountry_personal\\db\\UNITED KINGDOM – VISA OPTIONS AND GUIDE.docx', 'country': 'UNITED KINGDOM'}]
#
#  --->[Similarity score=0.793411]
# ●​ Spouse and children under 18 can join.
# ●​ Spouse can work without restriction; children can attend school.
# 📈 PR & Citizenship:
# ●​ ILR after 3 years if business meets success criteria (2 of 7 benchmarks, e.g., job
# creation, customer base growth).
# ●​ Citizenship eligible 1 year after ILR.
# 🆕 2025 Policy Highlights:
# ●​ No second endorsement needed at renewal/settlement.
# ●​ Secondary skilled employment allowed.
# ●​ Reduced number of endorsing bodies; greater scrutiny on business differentiation.
# ⚠️ Common Pitfalls:
# ●​ “Tech-washing” Generic Ideas: Many applicants relabel basic agencies or retail
# businesses as “tech-enabled”—these are rejected.
# ●​ Overlooking the Endorser’s Role: Each endorser has its own process. Some require
# multiple interviews and revisions; others have long queues.
# ●​ Incomplete Business Plans: Vague financials, no MVP timeline, or no UK-specific
# strategy leads to rejection.
# [{'producer': 'Skia/PDF m139 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'file_path': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'total_pages': 24, 'format': 'PDF 1.4', 'title': 'Practioner Notes For LLM', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 1, 'country': 'NA'}]
#
#  --->[Similarity score=0.793167]
# 📈 PR & Citizenship:
# ●​ After 1 year, transition to self-employed residence permit (renewable).
# ●​ PR after 5 years; citizenship after 5 years + Dutch language and civic integration.
# 🆕 2025 Policy Highlights:
# ●​ Facilitator list trimmed to top 25 firms.
# ●​ IND now conducts performance checks on facilitators.
# ●​ Digital submission and permit renewal introduced.
# ⚠️ Common Pitfalls:
# ●​ Facilitator Bottlenecks: Few facilitators available, and many refuse applicants with
# weak MVP or no traction.
# ●​ Founder Passivity: IND checks if founder is actively leading—not a remote or
# outsourced applicant.
# ●​ Mismatch of Innovation: “New to Dutch market” is judged strictly; global ideas already
# in EU may not qualify.
# ●​ Underestimating Timeline: Must switch from startup permit to self-employed permit
# after 12 months. Failing to meet IND expectations can block extension.
# [{'producer': 'Skia/PDF m139 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'file_path': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'total_pages': 24, 'format': 'PDF 1.4', 'title': 'Practioner Notes For LLM', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 17, 'country': 'NA'}]
#
#  --->[Similarity score=0.792236]
# ●​ Startup must show:
# ○​ Innovation and technological differentiation.
# ○​ Job creation potential.
# ○​ Alignment with local market needs.
# ●​ Support letters from German chambers (IHK) or economic boards are helpful.
# 👨‍👩‍👧 Family Relocation:
# ●​ Spouse and children eligible.
# ●​ Spouse may require basic German.
# 📈 PR & Citizenship:
# ●​ PR after 3 years if business is successful (steady revenue, job creation).
# ●​ Citizenship after 6–8 years (language, integration, tax compliance).
# 🆕 2025 Policy Highlights:
# ●​ Capital waivers for select AI, medtech, and clean energy startups.
# ●​ Regional support agencies empowered to fast-track approvals.
# ⚠️ Common Pitfalls:
# ●​ Lack of Regional Fit: Business not aligned to local economy or seen as 'imported
# without value' may be rejected.
# ●​ Generic Business Models: e.g., marketing agencies, ecommerce stores, drop shipping
# businesses often rejected unless they prove tech/IP advantage.
# [{'producer': 'Skia/PDF m139 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'file_path': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'total_pages': 24, 'format': 'PDF 1.4', 'title': 'Practioner Notes For LLM', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 13, 'country': 'NA'}]
#
#  --->[Similarity score=0.791460]
# ●​ Compliance Misses: Founders must attend regular check-ins with endorsers
# post-approval. Missing these can lead to visa curtailment.
# ●​ Delayed Incorporation: Delay in setting up a UK company and opening a bank account
# weakens business credibility.
# ●​ Innovation Saturation: Repeat ideas already endorsed in the UK ecosystem are often
# declined. Endorsers look for market gaps.
#
# 🇨🇦 Canada – Start-Up Visa (SUV)
#
# 📋 Eligibility:
# ●​ Endorsement: Must secure a Letter of Support from one of the following:
# ○​ VC fund committing at least CAD $200,000.
# ○​ Angel investor group committing at least CAD $75,000.
# ○​ Designated incubator (no minimum funding).
# ●​ Ownership: Up to 5 co-founders allowed per startup. Each must hold at least 10% of
# shares.
# ●​ Language: Minimum CLB 5 in English or French (IELTS: Listening 5, Reading 4, Writing
# 5, Speaking 5).
# ●​ Settlement Funds: Proof of liquid personal savings (e.g., CAD $26,170 for family of
# four).
# 🧾 Application Process:
# [{'producer': 'Skia/PDF m139 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'file_path': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'total_pages': 24, 'format': 'PDF 1.4', 'title': 'Practioner Notes For LLM', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 2, 'country': 'NA'}]
#
#  --->[Similarity score=0.790972]
# 1.​ Prepare and submit a full application to INIS, including:
# ○​ Business plan with financial forecasts, team structure, marketing and export
# plans.
# ○​ CV, police clearance, passport, and personal statement.
# ○​ Personal bank statements (last 6 months) and explanation of fund source.
# 2.​ INIS forwards to the Evaluation Committee.
# 3.​ If approved, receive a 2-year residence permit (Stamp 4).
# 4.​ Renewable if business is operational and compliant.
# 🧠 Business Requirements:
# ●​ Must generate 10+ jobs and €1 million in sales over 3–5 years.
# ●​ Company must be incorporated in Ireland.
# ●​ Real operational presence (office, bank account, staff).
# ●​ Technology, international growth, or IP focus preferred.
# 👨‍👩‍👧 Family Relocation:
# ●​ Spouse and dependent children under 18 included.
# ●​ Children can study in Ireland's public education system.
# 📈 PR & Citizenship:
# ●​ Eligible for long-term residency after 5 years.
# ●​ Citizenship requires 5 years of legal residence and integration.
# [{'producer': 'Skia/PDF m139 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'file_path': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'total_pages': 24, 'format': 'PDF 1.4', 'title': 'Practioner Notes For LLM', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 4, 'country': 'NA'}]
#
#  --->[Similarity score=0.789242]
# 3. Suitability Requirements
#
# General Grounds for Refusal: Must not fall for refusal under Part 9 (criminality, deception, etc.).
#
# Immigration Status: If applying in-country, must not be in breach of immigration laws (except for certain overstaying exceptions) or on immigration bail.
#
# 4. Eligibility Requirements (Points-Based)
#
# Applicants must score 70 points:
#
# 50 points from either:
#
# New Business Criteria (for new businesses)
#
# Same Business Criteria (for those continuing a previously endorsed business)
#
# 10 points for English language (B2 level)
#
# 10 points for financial requirement
#
# A. New Business Criteria (for most applicants)
#
# Business Plan: 30 points for a credible, detailed plan.
#
# Innovation, Viability, Scalability: 20 points if the business is:
#
# Innovative: Original, unique, or new to the UK market.
#
# Viable: Realistic, with potential for growth and job creation.
#
# Scalable: Potential for national/international expansion.
#
# B. Same Business Criteria (for those previously endorsed)
# [{'source': 'D:\\NextCountry_personal\\db\\UNITED KINGDOM – VISA OPTIONS AND GUIDE.docx', 'country': 'UNITED KINGDOM'}]
#
#  --->[Similarity score=0.786307]
# ●​ Age & Language: Applicant must be 18+ and meet CEFR B2 English level (IELTS 5.5
# equivalent).
# ●​ Maintenance Funds: Must show personal savings of at least £1,270 maintained for 28
# days.
# ●​ Investment Requirement: No longer mandatory for most.
# 🧾 Application Process:
# 1.​ Submit a pitch + business plan (showing exactly how the idea is viable, scalable and
# innovative) , financial forecasts, demo video of how the product or service works to the
# endorsing body.
# 2.​ Attend interview with the endorsing body
# [{'producer': 'Skia/PDF m139 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'file_path': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'total_pages': 24, 'format': 'PDF 1.4', 'title': 'Practioner Notes For LLM', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0, 'country': 'NA'}]
#
#  --->[Similarity score=0.786135]
# 📋 Eligibility:
# ●​ Funding: Minimum €50,000 from personal savings, angel investment, or venture capital.
# ●​ Business Innovation: Must be scalable, job-creating, and export-oriented.
# ●​ Founder Role: Applicant must play an active role in development and management.
# ●​ Ownership: More than 50% ownership of the Irish legal entity.
# ●​ Clean Record: Certificate of good character; no serious convictions.
# ●​ Language: No test required, but application must be in clear, professional English.
# 🧾 Application Process:
# 1.​ Prepare and submit a full application to INIS, including:
# ○​ Business plan with financial forecasts, team structure, marketing and export
# plans.
# ○​ CV, police clearance, passport, and personal statement.
# ○​ Personal bank statements (last 6 months) and explanation of fund source.
# 2.​ INIS forwards to the Evaluation Committee.
# 3.​ If approved, receive a 2-year residence permit (Stamp 4).
# 4.​ Renewable if business is operational and compliant.
# [{'producer': 'Skia/PDF m139 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'file_path': 'D:\\NextCountry_personal\\db\\Master Document  - STARTUP VISA PROGRAMS (GROUP 1 COUNTRIES).pdf', 'total_pages': 24, 'format': 'PDF 1.4', 'title': 'Practioner Notes For LLM', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 8, 'country': 'NA'}]
